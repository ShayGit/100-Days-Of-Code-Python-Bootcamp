# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  ...     Group
# 0             Accounting  ...  Business
# 1  Aerospace Engineering  ...      STEM
# 2            Agriculture  ...  Business
# 3           Anthropology  ...      HASS
# 4           Architecture  ...  Business
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  ...  Group
# 0                 False  ...  False
# 1                 False  ...  False
# 2                 False  ...  False
# 3                 False  ...  False
# 4                 False  ...  False
# 5                 False  ...  False
# 6                 False  ...  False
# 7                 False  ...  False
# 8                 False  ...  False
# 9                 False  ...  False
# 10                False  ...  False
# 11                False  ...  False
# 12                False  ...  False
# 13                False  ...  False
# 14                False  ...  False
# 15                False  ...  False
# 16                False  ...  False
# 17                False  ...  False
# 18                False  ...  False
# 19                False  ...  False
# 20                False  ...  False
# 21                False  ...  False
# 22                False  ...  False
# 23                False  ...  False
# 24                False  ...  False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  ...  Group
# 46             Psychology  ...   HASS
# 47               Religion  ...   HASS
# 48              Sociology  ...   HASS
# 49                Spanish  ...   HASS
# 50  Source: PayScale Inc.  ...    NaN
#
# [5 rows x 6 columns]

# %%
clean_df = df.dropna()

# %%
clean_df.tail()
# Out:
#    Undergraduate Major  ...  Group
# 45   Political Science  ...   HASS
# 46          Psychology  ...   HASS
# 47            Religion  ...   HASS
# 48           Sociology  ...   HASS
# 49             Spanish  ...   HASS
#
# [5 rows x 6 columns]

# %%
max_starting = clean_df['Starting Median Salary'].max()

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                             74300
# Mid-Career Median Salary                           91700
# Mid-Career 10th Percentile Salary                  66400
# Mid-Career 90th Percentile Salary                 124000
# Group                                               STEM
# Name: 43, dtype: object

# %%
clean_df['Undergraduate Major'].loc[clean_df['Mid-Career Median Salary'].idxmax()]
# Out:
# 'Chemical Engineering'

# %%
clean_df[['Undergraduate Major','Starting Median Salary']].loc[clean_df['Starting Median Salary'].idxmin()]
# Out:
# Undergraduate Major       Spanish
# Starting Median Salary      34000
# Name: 49, dtype: object

# %%
clean_df[['Undergraduate Major','Mid-Career Median Salary']].loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major         Education
# Mid-Career Median Salary        52000
# Name: 18, dtype: object

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
spread_col
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
clean_df.insert(1, 'Spread', spread_col)

# %%
clean_df.head()
# Out:
#      Undergraduate Major    Spread  ...  Mid-Career 90th Percentile Salary     Group
# 0             Accounting  109800.0  ...                           152000.0  Business
# 1  Aerospace Engineering   96700.0  ...                           161000.0      STEM
# 2            Agriculture  113700.0  ...                           150000.0  Business
# 3           Anthropology  104200.0  ...                           138000.0      HASS
# 4           Architecture   85400.0  ...                           136000.0  Business
#
# [5 rows x 7 columns]

# %%
clean_df.sort_values('Spread', ascending= True)[['Undergraduate Major','Spread']]
# Out:
#                      Undergraduate Major    Spread
# 40                               Nursing   50700.0
# 43                   Physician Assistant   57600.0
# 41                             Nutrition   65300.0
# 49                               Spanish   65400.0
# 27            Health Care Administration   66400.0
# 47                              Religion   66700.0
# 23                              Forestry   70000.0
# 32                       Interior Design   71300.0
# 18                             Education   72700.0
# 15                      Criminal Justice   74800.0
# 26                        Graphic Design   76000.0
# 31           Information Technology (IT)   84500.0
# 10                     Civil Engineering   84600.0
# 4                           Architecture   85400.0
# 48                             Sociology   87300.0
# 29                 Hospitality & Tourism   88500.0
# 24                             Geography   92000.0
# ...

# %%
clean_df.sort_values('Mid-Career 90th Percentile Salary', ascending= False)[['Undergraduate Major','Mid-Career 90th Percentile Salary']].iloc[0:5]

# %%
clean_df.sort_values('Spread', ascending= False)[['Undergraduate Major','Spread']]

# %%
pd.options.display.float_format= '{:,.2f}'.format

# %%
clean_df.groupby('Group').mean()
# Out:
#              Spread  ...  Mid-Career 90th Percentile Salary
# Group                ...
# Business 103,958.33  ...                         147,525.00
# HASS      95,218.18  ...                         129,363.64
# STEM     101,600.00  ...                         157,625.00
#
# [3 rows x 5 columns]
